# %%
import numpy as np
import pandas as pd
import re

# %%
row_data = pd.read_csv("G:/My Stuff/2_ML/Projects/House Pricing/dataset/house_prices.csv")

# %%
row_data
# Out:
#          Index                                              Title  \
# 0            0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1            1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2            2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3            3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4            4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
# ...        ...                                                ...
# 187526  187526  3 BHK Ready to Occupy Flat for sale in Bollywo...
# 187527  187527  3 BHK Ready to Occupy Flat for sale in Sushma ...
# 187528  187528  3 BHK Ready to Occupy Flat for sale in Bollywo...
# 187529  187529  2 BHK Ready to Occupy Flat for sale in Friends...
# 187530  187530  3 BHK Ready to Occupy Flat for sale in Affinit...
#
#                                               Description Amount(in rupees)  \
# 0       Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# ...

# %%
row_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Title              187531 non-null  object
#  2   Description        184508 non-null  object
#  3   Amount(in rupees)  187531 non-null  object
#  4   Price (in rupees)  169866 non-null  float64
#  5   location           187531 non-null  object
#  6   Carpet Area        106858 non-null  object
#  7   Status             186916 non-null  object
#  8   Floor              180454 non-null  object
#  9   Transaction        187448 non-null  object
#  10  Furnishing         184634 non-null  object
#  11  facing             117298 non-null  object
#  12  overlooking        106095 non-null  object
#  13  Society            77853 non-null   object
#  14  Bathroom           186703 non-null  object
# ...

# %%
dataset = row_data.copy()

# %%
dataset.drop(
['Index', 'Description', 'Ownership', 'overlooking','Car Parking','Dimensions','Plot Area','Super Area']
, axis='columns', inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Title              187531 non-null  object
#  1   Amount(in rupees)  187531 non-null  object
#  2   Price (in rupees)  169866 non-null  float64
#  3   location           187531 non-null  object
#  4   Carpet Area        106858 non-null  object
#  5   Status             186916 non-null  object
#  6   Floor              180454 non-null  object
#  7   Transaction        187448 non-null  object
#  8   Furnishing         184634 non-null  object
#  9   facing             117298 non-null  object
#  10  Society            77853 non-null   object
#  11  Bathroom           186703 non-null  object
#  12  Balcony            138596 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 18.6+ MB

# %%
dataset
# Out:
#                                                     Title Amount(in rupees)  \
# 0       1 BHK Ready to Occupy Flat for sale in Srushti...           42 Lac
# 1       2 BHK Ready to Occupy Flat for sale in Dosti V...           98 Lac
# 2       2 BHK Ready to Occupy Flat for sale in Sunrise...          1.40 Cr
# 3             1 BHK Ready to Occupy Flat for sale Kasheli           25 Lac
# 4       2 BHK Ready to Occupy Flat for sale in TenX Ha...          1.60 Cr
# ...                                                   ...               ...
# 187526  3 BHK Ready to Occupy Flat for sale in Bollywo...           63 Lac
# 187527  3 BHK Ready to Occupy Flat for sale in Sushma ...           55 Lac
# 187528  3 BHK Ready to Occupy Flat for sale in Bollywo...           76 Lac
# 187529  2 BHK Ready to Occupy Flat for sale in Friends...           30 Lac
# 187530  3 BHK Ready to Occupy Flat for sale in Affinit...          1.18 Cr
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Title              187531 non-null  object
#  1   Amount(in rupees)  187531 non-null  object
#  2   Price (in rupees)  169866 non-null  float64
#  3   location           187531 non-null  object
#  4   Carpet Area        106858 non-null  object
#  5   Status             186916 non-null  object
#  6   Floor              180454 non-null  object
#  7   Transaction        187448 non-null  object
#  8   Furnishing         184634 non-null  object
#  9   facing             117298 non-null  object
#  10  Society            77853 non-null   object
#  11  Bathroom           186703 non-null  object
#  12  Balcony            138596 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 18.6+ MB

# %%
dataset.isnull().sum()
# Out:
# Title                     0
# Amount(in rupees)         0
# Price (in rupees)     17665
# location                  0
# Carpet Area           80673
# Status                  615
# Floor                  7077
# Transaction              83
# Furnishing             2897
# facing                70233
# Society              109678
# Bathroom                828
# Balcony               48935
# dtype: int64

# %%
column = ['Title','location','Transaction','Furnishing','facing']
dataset[column] = dataset[column].fillna('Unknow')

mode_bathroom = dataset['Bathroom'].mode()
mode_balcony = dataset['Balcony'].mode()

dataset['Bathroom'] = dataset['Bathroom'].fillna(mode_bathroom)
dataset['Balcony'] = dataset['Balcony'].fillna(mode_balcony)

# %%
dataset.isnull().sum()
# Out:
# Title                     0
# Amount(in rupees)         0
# Price (in rupees)     17665
# location                  0
# Carpet Area           80673
# Status                  615
# Floor                  7077
# Transaction               0
# Furnishing                0
# facing                    0
# Society              109678
# Bathroom                828
# Balcony               48935
# dtype: int64

# %%
duplicates_row = dataset[dataset.duplicated(keep='first')]
duplicates_row.shape[0]
# Out:
# 120611

# %%
dataset.drop_duplicates(keep='first', inplace=True)

# %%
def convert_price(amount):
    try:
        if 'Lac' in amount:
            amount = amount.replace('Lac', '').strip()
            return float(amount)
        elif 'Cr' in amount:
            amount = amount.replace('Cr', '').strip()
            return float(amount) * 100
        else:
            return float(amount)
    except ValueError:
        return None

# %%
dataset['Amount(in rupees)'] = dataset['Amount(in rupees)'].apply(convert_price)

# %%
dataset['Carpet Area'] = dataset['Carpet Area'].astype(str)
dataset['Carpet Area'] = dataset['Carpet Area'].str.replace('sqft', '', regex=True)
dataset['Carpet Area'] = dataset['Carpet Area'].str.replace('sqm', '', regex=True)
dataset['Carpet Area'] = dataset['Carpet Area'].str.replace('sqyrd', '', regex=True)
dataset['Carpet Area'] = pd.to_numeric(dataset['Carpet Area'], errors='coerce')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66920 entries, 0 to 187530
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              66920 non-null  object
#  1   Amount(in rupees)  64048 non-null  float64
#  2   Price (in rupees)  61108 non-null  float64
#  3   location           66920 non-null  object
#  4   Carpet Area        37420 non-null  float64
#  5   Status             66621 non-null  object
#  6   Floor              64422 non-null  object
#  7   Transaction        66920 non-null  object
#  8   Furnishing         66920 non-null  object
#  9   facing             66920 non-null  object
#  10  Society            28700 non-null  object
#  11  Bathroom           66470 non-null  object
#  12  Balcony            48260 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 7.1+ MB

# %%
dataset.isnull().sum()
# Out:
# Title                    0
# Amount(in rupees)     2872
# Price (in rupees)     5812
# location                 0
# Carpet Area          29500
# Status                 299
# Floor                 2498
# Transaction              0
# Furnishing               0
# facing                   0
# Society              38220
# Bathroom               450
# Balcony              18660
# dtype: int64

# %%
dataset
# Out:
#                                                     Title  Amount(in rupees)  \
# 0       1 BHK Ready to Occupy Flat for sale in Srushti...               42.0
# 1       2 BHK Ready to Occupy Flat for sale in Dosti V...               98.0
# 2       2 BHK Ready to Occupy Flat for sale in Sunrise...              140.0
# 3             1 BHK Ready to Occupy Flat for sale Kasheli               25.0
# 4       2 BHK Ready to Occupy Flat for sale in TenX Ha...              160.0
# ...                                                   ...                ...
# 187526  3 BHK Ready to Occupy Flat for sale in Bollywo...               63.0
# 187527  3 BHK Ready to Occupy Flat for sale in Sushma ...               55.0
# 187528  3 BHK Ready to Occupy Flat for sale in Bollywo...               76.0
# 187529  2 BHK Ready to Occupy Flat for sale in Friends...               30.0
# 187530  3 BHK Ready to Occupy Flat for sale in Affinit...              118.0
#
# ...

# %%
dataset.isnull().sum()
# Out:
# Title                    0
# Amount(in rupees)     2872
# Price (in rupees)     5812
# location                 0
# Carpet Area          29500
# Status                 299
# Floor                 2498
# Transaction              0
# Furnishing               0
# facing                   0
# Society              38220
# Bathroom               450
# Balcony              18660
# dtype: int64

# %%
dataset['Bathroom'] = pd.to_numeric(dataset['Bathroom'], errors='coerce')
dataset['Balcony'] = pd.to_numeric(dataset['Balcony'], errors='coerce')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66920 entries, 0 to 187530
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              66920 non-null  object
#  1   Amount(in rupees)  64048 non-null  float64
#  2   Price (in rupees)  61108 non-null  float64
#  3   location           66920 non-null  object
#  4   Carpet Area        37420 non-null  float64
#  5   Status             66621 non-null  object
#  6   Floor              64422 non-null  object
#  7   Transaction        66920 non-null  object
#  8   Furnishing         66920 non-null  object
#  9   facing             66920 non-null  object
#  10  Society            28700 non-null  object
#  11  Bathroom           66438 non-null  float64
#  12  Balcony            48242 non-null  float64
# dtypes: float64(5), object(8)
# memory usage: 7.1+ MB

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
test_to_numeric = ['Title','location','Transaction','Furnishing','facing','Status','Floor','Society']

for x in test_to_numeric:
    dataset[x] = label_encoder.fit_transform(dataset[x])

# %%
dataset
# Out:
#         Title  Amount(in rupees)  Price (in rupees)  location  Carpet Area  \
# 0        3728               42.0             6000.0        67        500.0
# 1       11436               98.0            13799.0        67        473.0
# 2       16175              140.0            17500.0        67        779.0
# 3        1054               25.0                NaN        67        530.0
# 4       16392              160.0            18824.0        67        635.0
# ...       ...                ...                ...       ...          ...
# 187526  22721               63.0             3225.0        80          NaN
# 187527  27990               55.0             3274.0        80          NaN
# 187528  22721               76.0             4343.0        80       1250.0
# 187529  11695               30.0             4231.0        80          NaN
# 187530  21919              118.0             6162.0        80          NaN
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66920 entries, 0 to 187530
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              66920 non-null  int64
#  1   Amount(in rupees)  64048 non-null  float64
#  2   Price (in rupees)  61108 non-null  float64
#  3   location           66920 non-null  int64
#  4   Carpet Area        37420 non-null  float64
#  5   Status             66920 non-null  int64
#  6   Floor              66920 non-null  int64
#  7   Transaction        66920 non-null  int64
#  8   Furnishing         66920 non-null  int64
#  9   facing             66920 non-null  int64
#  10  Society            66920 non-null  int64
#  11  Bathroom           66438 non-null  float64
#  12  Balcony            48242 non-null  float64
# dtypes: float64(5), int64(8)
# memory usage: 7.1 MB

# %%
dataset.isnull().sum()
# Out:
# Title                    0
# Amount(in rupees)     2872
# Price (in rupees)     5812
# location                 0
# Carpet Area          29500
# Status                   0
# Floor                    0
# Transaction              0
# Furnishing               0
# facing                   0
# Society                  0
# Bathroom               482
# Balcony              18678
# dtype: int64

# %%
dataset = dataset.dropna()

# %%
dataset.isnull().sum()
# Out:
# Title                0
# Amount(in rupees)    0
# Price (in rupees)    0
# location             0
# Carpet Area          0
# Status               0
# Floor                0
# Transaction          0
# Furnishing           0
# facing               0
# Society              0
# Bathroom             0
# Balcony              0
# dtype: int64

# %%
dataset
# Out:
#         Title  Amount(in rupees)  Price (in rupees)  location  Carpet Area  \
# 0        3728               42.0             6000.0        67        500.0
# 9       26173              160.0            11150.0        67        900.0
# 13      29354              425.0            17526.0        67       1820.0
# 15      14393               90.0            10000.0        67        675.0
# 16       2794               37.0             5736.0        67        647.0
# ...       ...                ...                ...       ...          ...
# 187522  23590               80.0             4040.0        80       1200.0
# 187523  32202              119.0             4547.0        80       1705.0
# 187524  27988               69.6             5135.0        80        895.0
# 187525  26002               44.9             3904.0        80       1050.0
# 187528  22721               76.0             4343.0        80       1250.0
#
# ...

# %%
X = dataset[['Title', 'Bathroom', 'Carpet Area', 'location', 'Transaction', 'Furnishing', 'Balcony','facing','Price (in rupees)',
             'Status','Society','Floor']].values
y = dataset['Amount(in rupees)']

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train,y_train)
rf_model_preditctions = rf_model.predict(X_test)

r2_rf = r2_score(y_test, rf_model_preditctions)
mae_rf = mean_absolute_error(y_test, rf_model_preditctions)
rmse_rf = np.sqrt(((y_test - rf_model_preditctions) ** 2).mean())
mape_rf = mean_absolute_percentage_error(y_test, rf_model_preditctions)

print(f'R square of RandomForestRegressor -> {r2_rf}')
print(f'Mean absolute error of RandomForestRegressor -> {mae_rf}')
print(f'Root mean absolute error of RandomForestRegressor -> {rmse_rf}')
print(f'Mean absolute percentage error of RandomForestRegressor -> {mape_rf}')
